# %%
import gymnasium as gym
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# turns list of integers into an int
# Ex.
# build_state([1,2,3,4,5]) -> 12345
def build_state(features):
  return int("".join(map(lambda feature: str(int(feature)), features)))

# https://numpy.org/doc/stable/reference/generated/numpy.digitize.html 
# Return the indices of the bins to which each value in input array belongs.
def to_bin(value, bins):
  return np.digitize(x=[value], bins=bins)[0]

# %%
class FeatureTransformer:
  def __init__(self):
    # Note: to make this better you could look at how often each bin was
    # actually used while running the script.
    # It's not clear from the high/low values nor sample() what values
    # we really expect to get.
    self.cart_position_bins = np.linspace(-2.4, 2.4, 9)
    self.cart_velocity_bins = np.linspace(-2, 2, 9) # (-inf, inf) (I did not check that these were good values)
    self.pole_angle_bins = np.linspace(-0.4, 0.4, 9)
    self.pole_velocity_bins = np.linspace(-3.5, 3.5, 9) # (-inf, inf) (I did not check that these were good values)

  def transform(self, observation):
    # returns an int
    cart_pos, cart_vel, pole_angle, pole_vel = observation
    return build_state([
      to_bin(cart_pos, self.cart_position_bins),
      to_bin(cart_vel, self.cart_velocity_bins),
      to_bin(pole_angle, self.pole_angle_bins),
      to_bin(pole_vel, self.pole_velocity_bins),
    ])

# %%
class Model:
  def __init__(self, env, feature_transformer):
    self.env = env
    self.feature_transformer = feature_transformer

    # 10^4
    num_states = 10**env.observation_space.shape[0]
    num_actions = env.action_space.n
    self.Q = np.random.uniform(low=-1, high=1, size=(num_states, num_actions))

  def predict(self, s):
    x = self.feature_transformer.transform(s) # The state
    return self.Q[x]  # array of scores for each action given the state

  def update(self, s, a, G):
    x = self.feature_transformer.transform(s)
    # update rule from Q-learning
    self.Q[x,a] += 1e-2*(G - self.Q[x,a])

  def sample_action(self, s, eps):
    if np.random.random() < eps:
      return self.env.action_space.sample()
    else:
      p = self.predict(s)
      return np.argmax(p)

# %%
def play_one(model, eps, gamma):
  observation = tuple(env.reset()[0])
  done = False
  totalreward = 0
  iters = 0
  while not done and iters < 10000:
    action = model.sample_action(observation, eps)
    prev_observation = observation
    observation, reward, done, trunc, info = env.step(action)

    totalreward += reward

    if done and iters < 199:
      # failed. make reward/penalty be large
      reward = -300

    # update the model
    # update rule from Q-learning
    G = reward + gamma*np.max(model.predict(observation))
    model.update(prev_observation, action, G)

    iters += 1

  return totalreward

# %%
def plot_running_avg(totalrewards):
  N = len(totalrewards)
  running_avg = np.empty(N)
  for t in range(N):
    running_avg[t] = totalrewards[max(0, t-100):(t+1)].mean()
  plt.plot(running_avg)
  plt.title("Running Average")
  plt.show()

# %%
env = gym.make('CartPole-v1')
ft = FeatureTransformer()
model = Model(env, ft)
gamma = 0.9

N = 10000
totalrewards = np.empty(N)
for n in range(N):
    # stop sampling so much once we get more samples
    eps = 1.0/np.sqrt(n+1)
    totalreward = play_one(model, eps, gamma)
    totalrewards[n] = totalreward
    if n % 100 == 0:
        print("episode:", n, "total reward:", totalreward, "eps:", eps)
print("avg reward for last 100 episodes:", totalrewards[-100:].mean())
print("total steps:", totalrewards.sum())

plt.plot(totalrewards)
plt.title("Rewards")
plt.show()
# Out:
# episode: 0 total reward: 19.0 eps: 1.0
# episode: 100 total reward: 49.0 eps: 0.09950371902099892
# episode: 200 total reward: 34.0 eps: 0.07053456158585983
# episode: 300 total reward: 76.0 eps: 0.0576390417704235
# episode: 400 total reward: 87.0 eps: 0.04993761694389223
# episode: 500 total reward: 101.0 eps: 0.04467670516087703
# episode: 600 total reward: 117.0 eps: 0.04079085082240021
# episode: 700 total reward: 173.0 eps: 0.0377694787300249
# episode: 800 total reward: 192.0 eps: 0.03533326266687867
# episode: 900 total reward: 171.0 eps: 0.03331483023263848
# episode: 1000 total reward: 122.0 eps: 0.0316069770620507
# episode: 1100 total reward: 88.0 eps: 0.03013743873394561
# episode: 1200 total reward: 178.0 eps: 0.028855492841238062
# episode: 1300 total reward: 186.0 eps: 0.027724348650071385
# episode: 1400 total reward: 187.0 eps: 0.02671658425726324
# episode: 1500 total reward: 137.0 eps: 0.025811286645983367
# episode: 1600 total reward: 62.0 eps: 0.02499219116020307
# episode: 1700 total reward: 127.0 eps: 0.024246432248443597
# episode: 1800 total reward: 170.0 eps: 0.02356368148131365
# episode: 1900 total reward: 216.0 eps: 0.02293553851298437
# episode: 2000 total reward: 141.0 eps: 0.022355091700494795
# episode: 2100 total reward: 126.0 eps: 0.021816595214404266
# episode: 2200 total reward: 199.0 eps: 0.021315227815974374
# episode: 2300 total reward: 154.0 eps: 0.02084690996125416
# episode: 2400 total reward: 247.0 eps: 0.02040816326530612
# episode: 2500 total reward: 143.0 eps: 0.01999600119960014
# episode: 2600 total reward: 90.0 eps: 0.0196078431372549
# episode: 2700 total reward: 205.0 eps: 0.019241446072101123
# episode: 2800 total reward: 188.0 eps: 0.018894849871330582
# episode: 2900 total reward: 170.0 eps: 0.018566333001716968
# episode: 3000 total reward: 167.0 eps: 0.01825437644092281
# episode: 3100 total reward: 74.0 eps: 0.017957634043632188
# episode: 3200 total reward: 150.0 eps: 0.01767490804100673
# episode: 3300 total reward: 179.0 eps: 0.01740512865461766
# episode: 3400 total reward: 150.0 eps: 0.017147337032429676
# episode: 3500 total reward: 246.0 eps: 0.01690067088544646
# episode: 3600 total reward: 179.0 eps: 0.016664352333993333
# episode: 3700 total reward: 154.0 eps: 0.016437677572823703
# episode: 3800 total reward: 176.0 eps: 0.01622000804188198
# episode: 3900 total reward: 149.0 eps: 0.01601076285016887
# episode: 4000 total reward: 152.0 eps: 0.015809412247806517
# episode: 4100 total reward: 169.0 eps: 0.015615471979112765
# episode: 4200 total reward: 122.0 eps: 0.015428498379527544
# episode: 4300 total reward: 142.0 eps: 0.015248084103296531
# episode: 4400 total reward: 171.0 eps: 0.015073854388204487
# episode: 4500 total reward: 168.0 eps: 0.014905463779355262
# episode: 4600 total reward: 149.0 eps: 0.014742593246782542
# episode: 4700 total reward: 100.0 eps: 0.014584947642137372
# episode: 4800 total reward: 246.0 eps: 0.014432253448298278
# episode: 4900 total reward: 146.0 eps: 0.014284256782850143
# episode: 5000 total reward: 90.0 eps: 0.014140721622265264
# episode: 5100 total reward: 148.0 eps: 0.014001428218521149
# episode: 5200 total reward: 245.0 eps: 0.013866171683985996
# episode: 5300 total reward: 204.0 eps: 0.013734760723838819
# episode: 5400 total reward: 129.0 eps: 0.013607016498184134
# episode: 5500 total reward: 163.0 eps: 0.013482771598464758
# episode: 5600 total reward: 180.0 eps: 0.01336186912484746
# episode: 5700 total reward: 124.0 eps: 0.013244161853017133
# episode: 5800 total reward: 119.0 eps: 0.013129511480316922
# episode: 5900 total reward: 145.0 eps: 0.013017787942456283
# episode: 6000 total reward: 162.0 eps: 0.012908868793110689
# episode: 6100 total reward: 140.0 eps: 0.012802638639684321
# episode: 6200 total reward: 181.0 eps: 0.012698988629324323
# episode: 6300 total reward: 321.0 eps: 0.012597815979981676
# episode: 6400 total reward: 176.0 eps: 0.01249902355192602
# episode: 6500 total reward: 188.0 eps: 0.01240251945565374
# episode: 6600 total reward: 155.0 eps: 0.01230821669259179
# episode: 6700 total reward: 196.0 eps: 0.012216032825403858
# episode: 6800 total reward: 132.0 eps: 0.01212588967505907
# episode: 6900 total reward: 185.0 eps: 0.0120377130421331
# episode: 7000 total reward: 119.0 eps: 0.011951432450083671
# episode: 7100 total reward: 106.0 eps: 0.011866980908481739
# episode: 7200 total reward: 208.0 eps: 0.01178429469439066
# episode: 7300 total reward: 235.0 eps: 0.011703313150272007
# episode: 7400 total reward: 174.0 eps: 0.011623978496961555
# episode: 7500 total reward: 285.0 eps: 0.01154623566040508
# episode: 7600 total reward: 210.0 eps: 0.011470032110973345
# episode: 7700 total reward: 156.0 eps: 0.011395317714291038
# episode: 7800 total reward: 154.0 eps: 0.011322044592617122
# episode: 7900 total reward: 166.0 eps: 0.011250166995905777
# episode: 8000 total reward: 175.0 eps: 0.01117964118175896
# episode: 8100 total reward: 171.0 eps: 0.011110425303554916
# episode: 8200 total reward: 190.0 eps: 0.0110424793061026
# episode: 8300 total reward: 126.0 eps: 0.010975764828230913
# episode: 8400 total reward: 163.0 eps: 0.010910245111774533
# episode: 8500 total reward: 105.0 eps: 0.01084588491646583
# episode: 8600 total reward: 162.0 eps: 0.010782650440285157
# episode: 8700 total reward: 135.0 eps: 0.010720509244860595
# episode: 8800 total reward: 201.0 eps: 0.010659430185543134
# episode: 8900 total reward: 327.0 eps: 0.01059938334581489
# episode: 9000 total reward: 216.0 eps: 0.010540339975716555
# episode: 9100 total reward: 268.0 eps: 0.010482272434006255
# episode: 9200 total reward: 197.0 eps: 0.010425154133785426
# episode: 9300 total reward: 92.0 eps: 0.01036895949134883
# episode: 9400 total reward: 267.0 eps: 0.010313663878035112
# episode: 9500 total reward: 300.0 eps: 0.010259243574872122
# episode: 9600 total reward: 169.0 eps: 0.010205675729827259
# episode: 9700 total reward: 167.0 eps: 0.010152938317487875
# episode: 9800 total reward: 252.0 eps: 0.010101010101010102
# episode: 9900 total reward: 327.0 eps: 0.010049870596186849
# avg reward for last 100 episodes: 236.34
# total steps: 1642981.0

# %%
plot_running_avg(totalrewards)
